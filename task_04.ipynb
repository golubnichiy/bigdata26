# %% [markdown]
# #### Практическая работа – Проведение анализа тональности отзывов ресторанов

# %% [markdown]
# 1. Обработка данных
# 2. Исследоваельский анализ данных (визуализация)
# 3. Анализ тональности
