# %% [markdown]
# ### Практическая работа №3 – Построение рекомендательной системы
# 1. Загрузите датасет для создания рекомендательной системы (cosine similarity).
# 2. Проведите анализ данных используя Jupyter Notebook применяя методы, используемые на занятиях.
# 3. Итоговый файл отправьте на электронную почту artem@golubnichij.ru с темой письма Big Data 0326

# %%
https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset?select=Books.csv

# %%
https://www.kaggle.com/datasets/CooperUnion/anime-recommendations-database?select=rating.csv

# %% [markdown]
# https://www.kaggle.com/datasets/antonkozyriev/game-recommendations-on-steam?select=recommendations.csv

# %%
https://www.kaggle.com/datasets/athu1105/book-genre-prediction
